# %%
import pandas as pd

results_df = pd.read_csv('artifacts/data/retail-banking_summary.csv')
results_df
# Out:
#                                list_of_given_concepts  \
# 0             saving, transaction and saving, account
# 1   saving, transaction and saving, account and cu...
# 2   saving, transaction and saving, account and cu...
# 3   saving, transaction and saving, account and cu...
# 4   saving, transaction and saving, account and cu...
# 5   saving, transaction and saving, account and cu...
# 6   saving, transaction and saving, account and cu...
# 7   saving, transaction and saving, account and cu...
# 8   saving, transaction and saving, account and cu...
# 9   saving, transaction and saving, account and cu...
# 10  saving, transaction and saving, account and cu...
# 11  saving, transaction and saving, account and cu...
# 12  saving, transaction and saving, account and cu...
# 13  saving, transaction and saving, account and cu...
# 14  saving, transaction and saving, account and cu...
# 15  saving, transaction and saving, account and cu...
# ...

# %%
results_df['cosine_similarity'] = results_df['cosine_similarity'].apply(lambda x: round(x, 2) * 100)

# %%
results_df['list_of_given_concepts']
# Out:
# 0               saving, transaction and saving, account
# 1     saving, transaction and saving, account and cu...
# 2     saving, transaction and saving, account and cu...
# 3     saving, transaction and saving, account and cu...
# 4     saving, transaction and saving, account and cu...
# 5     saving, transaction and saving, account and cu...
# 6     saving, transaction and saving, account and cu...
# 7     saving, transaction and saving, account and cu...
# 8     saving, transaction and saving, account and cu...
# 9     saving, transaction and saving, account and cu...
# 10    saving, transaction and saving, account and cu...
# 11    saving, transaction and saving, account and cu...
# 12    saving, transaction and saving, account and cu...
# 13    saving, transaction and saving, account and cu...
# 14    saving, transaction and saving, account and cu...
# 15    saving, transaction and saving, account and cu...
# 16    saving, transaction and saving, account and cu...
# ...
