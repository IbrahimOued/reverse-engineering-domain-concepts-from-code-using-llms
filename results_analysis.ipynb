# %%
import pandas as pd

results_df = pd.read_csv('artifacts/data/retail-banking_summary.csv')
results_df
# Out:
#                      list_of_given_concepts  \
# 0                       saving, transaction
# 1   saving, transaction and saving, account
# 2   saving, transaction and saving, account
# 3   saving, transaction and saving, account
# 4   saving, transaction and saving, account
# 5   saving, transaction and saving, account
# 6   saving, transaction and saving, account
# 7   saving, transaction and saving, account
# 8   saving, transaction and saving, account
# 9   saving, transaction and saving, account
# 10  saving, transaction and saving, account
# 11  saving, transaction and saving, account
# 12  saving, transaction and saving, account
# 13  saving, transaction and saving, account
# 14  saving, transaction and saving, account
# 15  saving, transaction and saving, account
# 16  saving, transaction and saving, account
# 17  saving, transaction and saving, account
# 18  saving, transaction and saving, account
# 19  saving, transaction and saving, account
# ...
